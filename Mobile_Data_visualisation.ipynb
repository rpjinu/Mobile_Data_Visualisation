# %% [markdown]
# #A Case Study on Data Visulization using python

# %% [markdown]
# ## Problem Statement
#
# John is the owner of the Electronics shops. He has collected the data of sale. He opened his shop in 1990. Now he wanted to find which item sold the most out of all electronic items. He wants to do analysis on the mobile data. That data contains various columns such as battery power, clock speed, internal memory , ram size and touch screen etc. He wants to find various patterns and trends from the dataset. So data visualization is required to do this task.

# %% [markdown]
# ## Dataset Description
# <br>
#
# **battery_power** : Total energy a battery can store in one time measured in mAh
#
# **blue** : Has bluetooth or not
#
# **clock_speed** : speed at which microprocessor executes instructions
#
# **dual_sim** : Has dual sim support or not
#
# **fc** : Front Camera mega pixels
#
# **four_g** : Has 4G or not
#
# **int_memory** : Internal Memory in Gigabytes
#
# **m_dep** : Mobile Depth in cm
#
# **mobile_wt** : Weight of mobile phone
#
# **n_cores** : Number of cores of processor
#
# **pc** : Primary Camera mega pixels
#
# **px_height** : Pixel Resolution Height
#
# **px_width** : Pixel Resolution Width
#
# **ram** : Random Access Memory in Megabytes
#
# **sc_h** : Screen Height of mobile in cm
#
# **sc_w** : Screen Width of mobile in cm
#
# **talk_time** : longest time that a single battery charge will last.
#
# **three_g** : Mobile phone has 3G or not
#
# **touch_screen** : Mobile phone has touch screen or not
#
# **wifi** : Mobile phone has wifi or not
#
# **price_range** : Price Range of the mobile phone

# %% [markdown]
# ## <a id='toc0_'></a>Table of contents
# - [**A Case Study on Data Visulization using Python** ](#toc1_)
#   - [**1. Introduction**](#toc1_1_)
#       - [**What is Data Visulization**](#toc1_1_1_)
#   - [**2. Importing Necessary Libraries**](#toc1_2_)
#   - [**3. Loading Dataset**](#toc1_3_)
#       - [**Dropping the Unnecessaey columns.**](#toc1_3_1_)
#   - [**4. Perform Exploratory Data Analysis**](#toc1_4_)
#       - [**Find and handle the null values which are present in the dataset.**](#toc1_4_1_)
#       - [**Handling the Null vlaues.**](#toc1_4_2_)
#       - [**Find the duplicate values from the dataset and handle them if any presents.**](#toc1_4_3_)
#       - [**Count the numbers of Unique values in each column in given dataset.**](#toc1_4_4_)
#   - [**5. Data Visulization**](#toc1_5_)
#       - [**Countplot**](#toc1_5_1_)
#       - [**Histogram**](#toc1_5_2_)
#       - [**Pie Chart**](#toc1_5_3_)
#       - [**Violin Plot**](#toc1_5_4_)
#       - [**Bargraph**](#toc1_5_5_)
#       - [**Joint Plot**](#toc1_5_6_)
#       - [**Scatter Plot**](#toc1_5_7_)
#       - [**Box Plot**](#toc1_5_8_)
#       - [**Kde Plot**](#toc1_5_9)
#   - [**6. Conclusion**](#toc1_6_)

# %% [markdown]
# ## <a id='toc1_1_'></a>[1. Introduction](#toc0_)
# This case study aims to give an idea of how to find pattern or meaning from the given dataset.Data visualization provides a good, organized pictorial representation of the data which makes it easier to understand, observe, analyze.

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[What is Data Visulization](#toc0_)
#
# The process of finding trends and correlations in our data by representing it pictorially is called Data Visualization.

# %% [markdown]
# ## <a id='toc1_2_'></a>[2. Importing Necessary Liberaries](#toc0_)
#
# Here we are importing the libraries that are used in the code.<br>
#
# The following libraries are imported:<br>
# * Pandas - For Data Manuplation<br>
# * Numpy - for Numerical computation.<br>
# * seaborn and matplotlib and plotly - for beautiful data visualization <br>

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
#ignore warning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##Load dataset

# %%
df = pd.read_csv('/content/Mobile_Price_Data.csv') #loading the csv File to dataset

# %% [markdown]
# Here we are using the `head()` method to see the first five rows of the columns.

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# Let's find the shape of the dataset.
# It gives the number of rows and number of columns in the dataset.

# %%
df.shape
# Out:
# (2000, 21)

# %% [markdown]
# * Here we are going to take look at the names of the columns.<br>
#
# * We can use the `columns()` method to see the list that contains names of the columns.<br>

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# Let's take small look at the datatype of the values of each colum.<br>
#
# We can do it by using the `info()` method of the dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# As you can see, there are two columns with float values, one column with integer values, and ten more columns with object type values.

# %% [markdown]
# * Pandas `dataframe.corr()` method is used to find the pairwise correlation of all columns.

# %%
# find the pairwise correlation of all columns
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
# plotting the heatmap for the dataset
plt.figure(figsize = (10, 10))
tc = df.corr()
sns.heatmap(tc)
# Out:
# <Axes: >

# %% [markdown]
# * Here we can observe that battery_power, four_g, ram, DC, price range are the most correlated columns.

# %% [markdown]
# ## <a id='toc1_4_'></a>[4. Perform Exploratory Data Analysis](#toc0_)

# %% [markdown]
# ##check the null values

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# We're going to remove the rows that have null values.
# <br>
# Here we don't have null values so we are not droping any columns or row.
# <br>
#
# If the dataset has low numbers of the rows then we have to fill the null values by `Zero()`,`Mean()` and `median()` values.<br>

# %% [markdown]
# ##handling null value

# %%
df.dropna(inplace=True,axis=0) #droppinng the duplicated values.

# %% [markdown]
# ##check the duplicate

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The dataset contains no duplicate rows, as shown here.

# %% [markdown]
# ### <a id='toc1_4_4_'></a>[Count the numbers of  Unique values in each column in given dataset.](#toc0_)
# #### Get the number of unique values for each column
# * Here we are checking the null values for each columns. <br>
# * Here we are using `nunique()` method to get the numbers od unique values in columns <br>

# %%
for i in df.columns:
    print(i,df[i].nunique())
# Out:
# battery_power 1094
# blue 2
# clock_speed 26
# dual_sim 2
# fc 20
# four_g 2
# int_memory 63
# m_dep 10
# mobile_wt 121
# n_cores 8
# pc 21
# px_height 1137
# px_width 1109
# ram 1562
# sc_h 15
# sc_w 19
# talk_time 19
# three_g 2
# touch_screen 2
# wifi 2
# price_range 4

# %% [markdown]
# Here We are using the `value_counts()` method to check the unique values in each column.

# %%
df['four_g'].value_counts()
# Out:
# four_g
# 1    1043
# 0     957
# Name: count, dtype: int64

# %%
df['price_range'].value_counts()
# Out:
# price_range
# 1    500
# 2    500
# 3    500
# 0    500
# Name: count, dtype: int64

# %% [markdown]
# ## <a id='toc1_5_'></a>[5. Data Visualization ](#toc0_)

# %% [markdown]
# ### <a id='toc1_5_1_'></a>[Countplot](#toc0_)
# * One way to think of a count plot is as a histogram that is plotted over a categorical variable rather than a quantitative one.<br>
# * Bars are used to show how many observations fit into each group of classification.
# <br>

# %%
plt.tick_params(axis='both', which='major', labelsize=14) #it will increase the fontsize of the label
sns.countplot(x=df["dual_sim"],palette='Paired') #here we are defining the values of x axis and color palette
# Out:
# <Axes: xlabel='dual_sim', ylabel='count'>

# %% [markdown]
# According to this graph, we can deduce that only half of the customers are making use of dual SIMs while the other half are not.

# %%
plt.tick_params(axis='both', which='major', labelsize=14) #it will increase the fontsize of the label
sns.countplot(x=df["three_g"],palette='Paired') #here we are defining the values of x axis and color palette
# Out:
# <Axes: xlabel='three_g', ylabel='count'>

# %% [markdown]
# We can infer from this graph that the majority of consumers prefer mobile devices that are compatible with 3G.

# %%
plt.tick_params(axis='both', which='major', labelsize=14) #it will increase the fontsize of the label
sns.countplot(x=df["wifi"],palette='Paired') #here we are defining the values of x axis and color palette
# Out:
# <Axes: xlabel='wifi', ylabel='count'>

# %% [markdown]
# We can conclude that the same number of devices support wifi as the same number of devices do not.

# %%
plt.figure(figsize = (15, 10))
plt.tick_params(axis='both', which='major', labelsize=14) #it will increase the fontsize of the label
sns.countplot(x=df["clock_speed"],palette='Paired') #here we are defining the values of x axis and color palette
# Out:
# <Axes: xlabel='clock_speed', ylabel='count'>

# %% [markdown]
# here, we sees that clock speed of 0.

# %%
plt.tick_params(axis='both', which='major', labelsize=14) #it will increase the fontsize of the label
sns.countplot(x=df["touch_screen"],palette='Paired') #here we are defining the values of x axis and color palette
# Out:
# <Axes: xlabel='touch_screen', ylabel='count'>

# %% [markdown]
# As you can see there are same number of mobiles with touch screen and without it.

# %% [markdown]
# ### <a id='toc1_5_2_'></a>[Histogram](#toc0_)

# %% [markdown]
# Here, we'll count the amount of internal memory in each device's memory storage using the `histogram()` method of plotly library.

# %%
# counting the ram types
plt.figure(figsize = (10, 9))
sns.histplot(df['ram'])
# Out:
# <Axes: xlabel='ram', ylabel='Count'>

# %%
# plotting the line chart
fig = px.histogram(df, x="int_memory",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Comparing the RAM and Talk_Time
plt.figure(figsize = (15, 9))
ax = sns.histplot(df, x="ram", hue="talk_time")
sns.move_legend(ax, "center right")

# %% [markdown]
# Here, it can be seen that the vast bulk of talk time is conducted on mobile phones with 1500 MB of RAM.

# %% [markdown]
# ### <a id='toc1_5_3_'></a>[Pie chart](#toc0_)
# Pie chart visualization
#
# * We're using Plotly for the pie chart.
# * `pie()` function is used for plotting the pie chart, which contains `names` `labels` and  `color sequence` as arguments.
# * `update_traces()` function will update the position of the labels and textinfo. <br>

# %%
fig = px.pie(df, names='m_dep',labels={'m_dep':'m depart'},color_discrete_sequence=px.colors.sequential.RdBu) #px.pie
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the pie chart, we can say that the majority of the mobiles have a thickness of 0.1.

# %%
fig = px.pie(df, names='pc',labels={'pc':'pc'})
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Here, we observe that most of the mobiles have a primary camera with 10 megapixels.

# %% [markdown]
# ### <a id='toc1_5_4_'></a>[Violin Plot](#toc0_)
#
# A Violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data. It is used to visualize the distribution of numerical data. Unlike a box plot that can only show summary statistics, violin plots depict summary statistics and the density of each variable.

# %%
sns.violinplot(data=df, x="three_g",y="four_g")
# Out:
# <Axes: xlabel='three_g', ylabel='four_g'>

# %% [markdown]
# This means that all 4G phones also contain 3G technology, but not the other way around.

# %%
# plotting the violin plot
fig = px.violin(df, y="int_memory", x="price_range")

# showing the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the violin plot, we can understand the distribution of the internal memory in the various mobiles in their price ranges.
#
# * In categories 0 and 1, we can see a higher density toward low internal memory.
# * In category 3, we can say that higher density leads to greater internal memory.

# %% [markdown]
# ### <a id='toc1_5_5_'></a>[Bargraph](#toc0_)

# %% [markdown]
# * In the below bargraph we are comparing the price range with number of cores.
# * We can see that price range 2 has the highest number of cores.

# %%
# Here we are counting the number of cores that are present in their price range.
plt.figure(figsize = (10, 8))
plt.tick_params(axis='both', which='major', labelsize=14)
sns.barplot(data= df,x="price_range",y="n_cores", palette="mako")
# Out:
# <Axes: xlabel='price_range', ylabel='n_cores'>

# %%
plt.figure(figsize = (10, 8))
plt.tick_params(axis='both', which='major', labelsize=14)
sns.barplot(data= df,y="clock_speed",x="n_cores" , palette="rocket")
# Out:
# <Axes: xlabel='n_cores', ylabel='clock_speed'>

# %% [markdown]
# * From the above graph we can see that core number 1 has the highest clock speed of around 1.6.

# %% [markdown]
# ### <a id='toc1_5_6_'></a>[Joint Plot](#toc0_)
#
#
# Jointplot provides a convenient interface to the class of joint grid by using several types of points. It is intended for a lightweight wrapper; suppose we need more flexibility, we are using a joint grid directly. We draw a plot by using two variables to define the seaborn jointplot. It is very important; also, we are drawing two graphs using univariate and bivariate.

# %%
# Joint kernel density estimate
g = sns.jointplot(
    data=df,
    x="price_range", y="ram", hue="three_g",
    kind="kde",
)

# %% [markdown]
# This graph illustrates the relationship between RAM and price range in relation to 3G connectivity.
#
# * This indicates that 3G is extensively utilized in RAM and price levels.

# %%
h = sns.jointplot(
    data=df,
    x="three_g", y="four_g",
    kind="kde",
)

# %% [markdown]
# From this graph, we can say every mobile device that has 4G has 3G in it. However, it is not the opposite.

# %% [markdown]
# ### <a id='toc1_5_7_'></a>[Scatter Plot](#toc0_)
#
#
# A scatter plot uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axes indicates values for an individual data point. Scatter plots are used to observe relationships between variables.

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(data=df, x="battery_power", y="px_height", hue="four_g")
# Out:
# <Axes: xlabel='battery_power', ylabel='px_height'>

# %% [markdown]
# When we compare the pexel height and battery power of 4G and non-4G mobile devices, we can see that the distributions of both are very similar.

# %%
plt.figure(figsize = (16, 10))
plt.scatter(df["px_width"],df["px_height"])
plt.show()

# %% [markdown]
# From this, we may conclude that there is a huge variety of height and breadth combinations of pexels.

# %% [markdown]
# ### <a id='toc1_5_8_'></a>[Box plot](#toc0_)
#
# Box plots (also called box-and-whisker plots or box-whisker plots) give a good graphical image of the concentration of the data. They also show how far the extreme values are from most of the data. A box plot is constructed from five values: the minimum value, the first quartile, the median, the third quartile, and the maximum value.

# %%
plt.figure(figsize = (15, 6))
sns.boxplot(x='price_range', y='battery_power', data=df)
sns.set_style("dark")
plt.show()

# %% [markdown]
# As a result, we can conclude that as the price rises, so does the battery power.

# %%
fig = px.box(df, x="talk_time", y="battery_power")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# We can conclude that a battery capacity of 1000 to 1400 mAh is adequate for regular talk time.

# %% [markdown]
# ### <a id='toc1_5_9_'></a>[Pair Plot](#toc0_)

# %%
#sns.pairplot(df,hue='price_range',size=3)
#plt.show()

# %% [markdown]
# ### <a id='toc1_5_10_'></a>[Hexagonal Binning plot](#toc0_)

# %%
X=df["pc"]
Y=df["fc"]
# changing the rc parameters and plotting
plt.rcParams['figure.figsize'] = [15, 8]

# Plotting the hexbin plot
fig, ax = plt.subplots()
ax.hexbin(X, Y, gridsize=20)
#ax.set(xlim=(-1, 20), ylim=(-1, 20))  limiting the x and y axis for better visualization
plt.show()

# %% [markdown]
# This indicates that both the primary camera and the face camera are widely spread.

# %% [markdown]
# ### <a id='toc1_5_9_'></a>[Kde Plot](#toc0_)
#
# Kernel Distribution Estimation Plot which displays the probability density function of continuous or non-parametric data variables; thus, we are able to plot for both univariate and multivariate data sets.

# %%
sns.kdeplot(data=df, x="battery_power")
# Out:
# <Axes: xlabel='battery_power', ylabel='Density'>

# %% [markdown]
# Here, we can observe that the battery capacity ranges greatly from more than 500 to less than 2000.

# %%
sns.kdeplot(data=df, x="n_cores")
# Out:
# <Axes: xlabel='n_cores', ylabel='Density'>

# %% [markdown]
# Here, we can observe that the number of cores ranges from 1 to 9.

# %%
sns.kdeplot(data=df, x="talk_time", hue="four_g", multiple="stack")
# Out:
# <Axes: xlabel='talk_time', ylabel='Density'>

# %% [markdown]
# On devices without 4G, the talk time density is higher.

# %%
plt.figure(figsize = (10, 10))
sns.kdeplot(data=df, x="n_cores", y="price_range")
# Out:
# <Axes: xlabel='n_cores', ylabel='price_range'>

# %% [markdown]
# From the following, we can say :
# * In the price range of 0 to 1, there is a high density on 2 to 4 cores.<br>
# * There is a high density on 4 to 8 cores in the 2 to 3 price range.

# %%
sns.kdeplot( data=df, x="battery_power", y="mobile_wt", hue="price_range", fill=True)
# Out:
# <Axes: xlabel='battery_power', ylabel='mobile_wt'>

# %% [markdown]
# This plot shows that devices in price range 3 have a battery capacity of 1500-2000 mAH, while the rest are evenly distributed.

# %% [markdown]
# ## <a id='toc1_6_'></a>[6. Conclusion](#toc0_)

# %% [markdown]
# In this case study, we have examined various visualization techniques for better understading of the data.
